# %%
# !pip install keras-tuner

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import kerastuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import  Adam
import matplotlib.pyplot as plt
# Out:
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_10576\3481921458.py:5: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   import kerastuner as kt

# %%
df = pd.read_csv("Resources/charity_data.csv")
df.tail()
# Out:
#              EIN                                               NAME  \
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 34294   Association       1          0                      N      5000
# 34295   Association       1          0                      N      5000
# 34296   Association       1          0                      N      5000
# 34297   Association       1          0                      N      5000
# 34298  Co-operative       1      1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0

# %%
#drop non-essential columns
funding_df = df.drop(columns=["EIN", "NAME"], index=1)

# %%
# look for NA values
print(f"{funding_df.isna().any()} \n")
# look for duplicates
print(f"Duplicated rows: {df.duplicated().any()}")
# Out:
# APPLICATION_TYPE          False
# AFFILIATION               False
# CLASSIFICATION            False
# USE_CASE                  False
# ORGANIZATION              False
# STATUS                    False
# INCOME_AMT                False
# SPECIAL_CONSIDERATIONS    False
# ASK_AMT                   False
# IS_SUCCESSFUL             False
# dtype: bool
#
# Duplicated rows: False

# %%
funding_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8746
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# identify rare application types for binning 
funding_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27036
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
funding_df["APPLICATION_TYPE"].value_counts() < 10
# Out:
# T3     False
# T4     False
# T6     False
# T5     False
# T19    False
# T8     False
# T7     False
# T10    False
# T9     False
# T13    False
# T12    False
# T2     False
# T25     True
# T14     True
# T29     True
# T15     True
# T17     True
# Name: APPLICATION_TYPE, dtype: bool

# %%
def bin_outliers(df,col,ls):
    for x in ls:
        df[col] = df[col].replace(x, "other")
    return df

# %%
outliers = funding_df['APPLICATION_TYPE'].value_counts().loc[lambda x: x<200].index

bin_outliers(funding_df,'APPLICATION_TYPE',outliers)\
    .head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
# 5               T3       Independent          C1200  Preservation
#
#   ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0  Association       1              0                      N     5000
# 2  Association       1              0                      N     5000
# 3        Trust       1    10000-24999                      N     6692
# 4        Trust       1  100000-499999                      N   142590
# 5        Trust       1              0                      N     5000
#
#    IS_SUCCESSFUL
# 0              1
# 2              0
# 3              1
# 4              1
# 5              1

# %%
funding_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27036
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
funding_df['CLASSIFICATION'].value_counts().head(10)
# Out:
# C1000    17326
# C2000     6073
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# Name: CLASSIFICATION, dtype: int64

# %%
cls_outliers = funding_df['CLASSIFICATION'].value_counts().loc[lambda x: x<1000].index
cls_outliers
# Out:
# Index(['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100',
#        'C1300', 'C1280', 'C1230', 'C1400', 'C2300', 'C7200', 'C1240', 'C8000',
#        'C7120', 'C1500', 'C6000', 'C1800', 'C1250', 'C8200', 'C1238', 'C1278',
#        'C1237', 'C1235', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600',
#        'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256',
#        'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820',
#        'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570',
#        'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561',
#        'C4500', 'C2150'],
#       dtype='object')

# %%
bin_outliers(funding_df, 'CLASSIFICATION', cls_outliers)\
    .head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
# 5               T3       Independent          C1200  Preservation
#
#   ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0  Association       1              0                      N     5000
# 2  Association       1              0                      N     5000
# 3        Trust       1    10000-24999                      N     6692
# 4        Trust       1  100000-499999                      N   142590
# 5        Trust       1              0                      N     5000
#
#    IS_SUCCESSFUL
# 0              1
# 2              0
# 3              1
# 4              1
# 5              1

# %%
funding_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6073
# C1200     4837
# other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
funding_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34298 entries, 0 to 34298
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   APPLICATION_TYPE        34298 non-null  object
#  1   AFFILIATION             34298 non-null  object
#  2   CLASSIFICATION          34298 non-null  object
#  3   USE_CASE                34298 non-null  object
#  4   ORGANIZATION            34298 non-null  object
#  5   STATUS                  34298 non-null  int64
#  6   INCOME_AMT              34298 non-null  object
#  7   SPECIAL_CONSIDERATIONS  34298 non-null  object
#  8   ASK_AMT                 34298 non-null  int64
#  9   IS_SUCCESSFUL           34298 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 2.9+ MB

# %%
ask_outliers = funding_df['ASK_AMT'].loc[lambda x: x>1.0e+07]

# %%
ask_outliers.count()
# Out:
# 412

# %%
amt_high = funding_df[funding_df.ASK_AMT.isin(ask_outliers)]
amt_low = funding_df[~funding_df.ASK_AMT.isin(ask_outliers)]
amt_high.groupby('IS_SUCCESSFUL').count()
# amt_low.groupby('IS_SUCCESSFUL').count()
# Out:
#                APPLICATION_TYPE  AFFILIATION  CLASSIFICATION  USE_CASE  \
# IS_SUCCESSFUL
# 0                           242          242             242       242
# 1                           170          170             170       170
#
#                ORGANIZATION  STATUS  INCOME_AMT  SPECIAL_CONSIDERATIONS  \
# IS_SUCCESSFUL
# 0                       242     242         242                     242
# 1                       170     170         170                     170
#
#                ASK_AMT
# IS_SUCCESSFUL
# 0                  242
# 1                  170

# %%
funding_df['ASK_AMT'].value_counts()
# Out:
# 5000        25398
# 63981           3
# 6725            3
# 15583           3
# 10478           3
#             ...
# 3899729         1
# 5371754         1
# 30060           1
# 43091152        1
# 36500179        1
# Name: ASK_AMT, Length: 8746, dtype: int64

# %%
funding_df['ASK_AMT'].describe()
# Out:
# count    3.429800e+04
# mean     2.769276e+06
# std      8.713172e+07
# min      5.000000e+03
# 25%      5.000000e+03
# 50%      5.000000e+03
# 75%      7.738500e+03
# max      8.597806e+09
# Name: ASK_AMT, dtype: float64

# %%
funding_encoded = pd.get_dummies(funding_df, 
                                 columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION','USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'],
                                 drop_first=True)

# %%
funding_processed = funding_encoded.copy()

# %%
funding_processed
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T19  \
# 0           1      5000              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# 5           1      5000              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                        0                    0                    0
# 2                        0                    0                    1
# 3                        1                    0                    0
# 4                        1                    0                    0
# 5                        1                    0                    0
# ...                    ...                  ...                  ...
# 34294                    0                    1                    0
# 34295                    0                    1                    0
# 34296                    1                    0                    0
# 34297                    0                    0                    1
# 34298                    1                    0                    0
#
#        APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  ...  \
# 0                        0                    0                    0  ...
# 2                        0                    0                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# 5                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    0                    0  ...
# 34295                    0                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    0                    0  ...
# 34298                    0                    0                    0  ...
#
#        ORGANIZATION_Trust  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# 0                       0                  0                       0
# 2                       0                  0                       0
# 3                       1                  0                       1
# 4                       1                  0                       0
# 5                       1                  0                       0
# ...                   ...                ...                     ...
# 34294                   0                  0                       0
# 34295                   0                  0                       0
# 34296                   0                  0                       0
# 34297                   0                  0                       0
# 34298                   0                  0                       0
#
#        INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# 0                             0                   0                 0
# 2                             0                   0                 0
# 3                             0                   0                 0
# 4                             1                   0                 0
# 5                             0                   0                 0
# ...                         ...                 ...               ...
# 34294                         0                   0                 0
# 34295                         0                   0                 0
# 34296                         0                   0                 0
# 34297                         0                   0                 0
# 34298                         0                   0                 1
#
#        INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# 0                           0                0                  0
# 2                           0                0                  0
# 3                           0                0                  0
# 4                           0                0                  0
# 5                           0                0                  0
# ...                       ...              ...                ...
# 34294                       0                0                  0
# 34295                       0                0                  0
# 34296                       0                0                  0
# 34297                       0                0                  0
# 34298                       0                0                  0
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 2                             0
# 3                             0
# 4                             0
# 5                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34298 rows x 37 columns]

# %%
funding_processed.describe()
# Out:
#              STATUS       ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T19  \
# count  34298.000000  3.429800e+04   34298.000000          34298.000000
# mean       0.999854  2.769276e+06       0.532393              0.031051
# std        0.012073  8.713172e+07       0.498957              0.173459
# min        0.000000  5.000000e+03       0.000000              0.000000
# 25%        1.000000  5.000000e+03       0.000000              0.000000
# 50%        1.000000  5.000000e+03       1.000000              0.000000
# 75%        1.000000  7.738500e+03       1.000000              0.000000
# max        1.000000  8.597806e+09       1.000000              1.000000
#
#        APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# count         34298.000000         34298.000000         34298.000000
# mean              0.788268             0.044959             0.034200
# std               0.408542             0.207217             0.181746
# min               0.000000             0.000000             0.000000
# 25%               1.000000             0.000000             0.000000
# 50%               1.000000             0.000000             0.000000
# 75%               1.000000             0.000000             0.000000
# max               1.000000             1.000000             1.000000
#
#        APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  ...  \
# count         34298.000000         34298.000000         34298.000000  ...
# mean              0.035454             0.021138             0.021488  ...
# std               0.184927             0.143847             0.145007  ...
# min               0.000000             0.000000             0.000000  ...
# 25%               0.000000             0.000000             0.000000  ...
# 50%               0.000000             0.000000             0.000000  ...
# 75%               0.000000             0.000000             0.000000  ...
# max               1.000000             1.000000             1.000000  ...
#
#        ORGANIZATION_Trust  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# count        34298.000000       34298.000000            34298.000000
# mean             0.685608           0.021197                0.015832
# std              0.464280           0.144041                0.124826
# min              0.000000           0.000000                0.000000
# 25%              0.000000           0.000000                0.000000
# 50%              1.000000           0.000000                0.000000
# 75%              1.000000           0.000000                0.000000
# max              1.000000           1.000000                1.000000
#
#        INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# count              34298.000000        34298.000000      34298.000000
# mean                   0.098373            0.006997          0.027844
# std                    0.297823            0.083359          0.164529
# min                    0.000000            0.000000          0.000000
# 25%                    0.000000            0.000000          0.000000
# 50%                    0.000000            0.000000          0.000000
# 75%                    0.000000            0.000000          0.000000
# max                    1.000000            1.000000          1.000000
#
#        INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# count            34298.000000     34298.000000       34298.000000
# mean                 0.109248         0.004053           0.005394
# std                  0.311955         0.063533           0.073246
# min                  0.000000         0.000000           0.000000
# 25%                  0.000000         0.000000           0.000000
# 50%                  0.000000         0.000000           0.000000
# 75%                  0.000000         0.000000           0.000000
# max                  1.000000         1.000000           1.000000
#
#        SPECIAL_CONSIDERATIONS_Y
# count              34298.000000
# mean                   0.000787
# std                    0.028047
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                    1.000000
#
# [8 rows x 37 columns]

# %%
funding_processed.shape
# Out:
# (34298, 37)

# %%
funding_processed.to_csv('Resources/funding_processed.csv',index=False)

# %%
#split preprocessed data into features and target arrays
X = funding_processed.drop(columns=['IS_SUCCESSFUL','STATUS'])
#target array
y = funding_processed['IS_SUCCESSFUL'].values

# %%
def split_data(data, X, y, seed=5):
    """splits feature and target data into test and train sets and scales feature data

    Args:
        model (class): model class name
        X (array): array containing feature column values
        y (1D array): array containing target variable
        seed (int): random seed value; default=5
    """
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=seed)
    scaler = StandardScaler().fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test, X_train_scaled, X_test_scaled

# %%
X_train, X_test, y_train, y_test, X_train_scaled, X_test_scaled = split_data(df,X,y)

# %%
X_train.shape[1]
# Out:
# 36

# %%
# define initial model 
n_input = len(X_train_scaled[1])

nn_model = Sequential()

# hidden layers 1 and 2
nn_model.add(Dense(units=17, input_dim=n_input, activation="relu"))
nn_model.add(Dense(units= 5, activation="relu"))

# output layer
nn_model.add(Dense(units=1, activation="sigmoid"))

# view model structure
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 17)                629
#
#  dense_1 (Dense)             (None, 5)                 90
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 725
# Trainable params: 725
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# cp = callback that saves the model's weight every 5 epochs
file_path = 'base_model/callback_weight'
cp = tf.keras.callbacks.ModelCheckpoint(filepath=file_path, save_weights_only=True, save_freq=5)

# train the model and save the weights
nn_model.fit(X_train_scaled, y_train, epochs=100, callbacks=cp)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5375 - accuracy: 0.7373
# Epoch 2/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5376 - accuracy: 0.7375
# Epoch 3/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5377 - accuracy: 0.7379
# Epoch 4/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5375 - accuracy: 0.7379
# Epoch 5/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5377 - accuracy: 0.7375
# Epoch 6/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5373 - accuracy: 0.7374
# Epoch 7/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5379 - accuracy: 0.7384
# Epoch 8/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5377 - accuracy: 0.7388
# Epoch 9/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5377 - accuracy: 0.7368
# Epoch 10/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5373 - accuracy: 0.7383
# Epoch 11/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5371 - accuracy: 0.7374
# Epoch 12/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5378 - accuracy: 0.7383
# Epoch 13/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5373 - accuracy: 0.7373
# Epoch 14/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5373 - accuracy: 0.7372
# Epoch 15/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5376 - accuracy: 0.7379
# Epoch 16/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5375 - accuracy: 0.7378
# Epoch 17/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5374 - accuracy: 0.7372
# Epoch 18/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5379 - accuracy: 0.7384
# Epoch 19/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5374 - accuracy: 0.7381
# Epoch 20/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5375 - accuracy: 0.7381
# Epoch 21/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5372 - accuracy: 0.7381
# Epoch 22/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5372 - accuracy: 0.7372
# Epoch 23/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5371 - accuracy: 0.7372
# Epoch 24/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5377 - accuracy: 0.7363
# Epoch 25/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5371 - accuracy: 0.7389
# Epoch 26/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5376 - accuracy: 0.7374
# Epoch 27/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5374 - accuracy: 0.7383
# Epoch 28/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5372 - accuracy: 0.7385
# Epoch 29/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5373 - accuracy: 0.7380
# Epoch 30/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5370 - accuracy: 0.7379
# Epoch 31/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5374 - accuracy: 0.7379
# Epoch 32/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5373 - accuracy: 0.7377
# Epoch 33/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5372 - accuracy: 0.7387
# Epoch 34/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5376 - accuracy: 0.7388
# Epoch 35/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5372 - accuracy: 0.7379
# Epoch 36/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5372 - accuracy: 0.7381
# Epoch 37/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5374 - accuracy: 0.7389
# Epoch 38/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5370 - accuracy: 0.7381
# Epoch 39/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5371 - accuracy: 0.7382
# Epoch 40/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5373 - accuracy: 0.7372
# Epoch 41/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5371 - accuracy: 0.7386
# Epoch 42/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5371 - accuracy: 0.7388
# Epoch 43/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5372 - accuracy: 0.7378
# Epoch 44/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5373 - accuracy: 0.7384
# Epoch 45/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5373 - accuracy: 0.7376
# Epoch 46/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5373 - accuracy: 0.7388
# Epoch 47/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5371 - accuracy: 0.7378
# Epoch 48/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5372 - accuracy: 0.7391
# Epoch 49/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5374 - accuracy: 0.7382
# Epoch 50/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5370 - accuracy: 0.7378
# Epoch 51/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5371 - accuracy: 0.7382
# Epoch 52/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5373 - accuracy: 0.7375
# Epoch 53/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5369 - accuracy: 0.7390
# Epoch 54/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5372 - accuracy: 0.7383
# Epoch 55/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5371 - accuracy: 0.7379
# Epoch 56/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5369 - accuracy: 0.7390
# Epoch 57/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5367 - accuracy: 0.7379
# Epoch 58/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5369 - accuracy: 0.7386
# Epoch 59/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5369 - accuracy: 0.7383
# Epoch 60/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5369 - accuracy: 0.7388
# Epoch 61/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5372 - accuracy: 0.7376
# Epoch 62/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5371 - accuracy: 0.7385
# Epoch 63/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5370 - accuracy: 0.7376
# Epoch 64/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5367 - accuracy: 0.7382
# Epoch 65/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5367 - accuracy: 0.7390
# Epoch 66/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5372 - accuracy: 0.7381
# Epoch 67/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5369 - accuracy: 0.7380
# Epoch 68/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5368 - accuracy: 0.7388
# Epoch 69/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5370 - accuracy: 0.7386
# Epoch 70/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5368 - accuracy: 0.7386
# Epoch 71/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5366 - accuracy: 0.7387
# Epoch 72/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5369 - accuracy: 0.7388
# Epoch 73/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5367 - accuracy: 0.7390
# Epoch 74/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5370 - accuracy: 0.7392
# Epoch 75/100
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5366 - accuracy: 0.7386
# Epoch 76/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5368 - accuracy: 0.7381
# Epoch 77/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5369 - accuracy: 0.7382
# Epoch 78/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5364 - accuracy: 0.7392
# Epoch 79/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5369 - accuracy: 0.7376
# Epoch 80/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5368 - accuracy: 0.7372
# Epoch 81/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5366 - accuracy: 0.7377
# Epoch 82/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5369 - accuracy: 0.7381
# Epoch 83/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5368 - accuracy: 0.7375
# Epoch 84/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 85/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5367 - accuracy: 0.7388
# Epoch 86/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5370 - accuracy: 0.7385
# Epoch 87/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5369 - accuracy: 0.7382
# Epoch 88/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5368 - accuracy: 0.7393
# Epoch 89/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5366 - accuracy: 0.7384
# Epoch 90/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5366 - accuracy: 0.7376
# Epoch 91/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 92/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5367 - accuracy: 0.7395
# Epoch 93/100
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5367 - accuracy: 0.7379
# Epoch 94/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5365 - accuracy: 0.7376
# Epoch 95/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5364 - accuracy: 0.7392
# Epoch 96/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5365 - accuracy: 0.7381
# Epoch 97/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5367 - accuracy: 0.7392
# Epoch 98/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5368 - accuracy: 0.7380
# Epoch 99/100
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 100/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5367 - accuracy: 0.7375

# %%
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5654 - accuracy: 0.7279 - 235ms/epoch - 875us/step
# Loss: 0.5654239058494568, Accuracy: 0.7279300093650818
